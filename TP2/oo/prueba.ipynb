# %%
import clases
import matplotlib.pyplot as plt

# %%
pendulo = clases.fuzzy_logic(250,180,20,'pendulo')#fmax,pmax,vmax,tipo,defuzz; centroid/bisector/MOM/SOM/LOM default:centroid  
print("1")
pendulo.func_pertenencia()
print("2")


carrito = clases.fuzzy_logic(250,100,50,'carrito')
carrito.func_pertenencia()


test = clases.pendulo(0.002, 0.001, 35, 0.5, 0,2,1,1)
test.simular(pendulo,carrito)
# Out:
# 1
# 2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 12
#       8 carrito.func_pertenencia()
#      11 test = clases.pendulo(0.002, 0.001, 35, 0.5, 0,2,1,1)
# ---> 12 test.simular(pendulo,carrito)
#
# File ~/programacion/IA_II_Grupo_4/TP2/oo/clases.py:212, in pendulo.simular(self, obj, obj2)
#     210 self.vel = self.vel + self.acel * self.delta_t
#     211 theta = theta + self.vel * self.delta_t + self.acel * np.power(self.delta_t, 2) / 2
# --> 212 if theta > np.pi:
#     213     theta = theta - 2 * np.pi
#     214 elif theta < -np.pi:
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
